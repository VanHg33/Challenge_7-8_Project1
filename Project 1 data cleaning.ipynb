# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# Read each quarter for each year of Metropolitan Median House Price Data Files and store into Pandas DataFrames

Q1_2015 = pd.read_csv(Path("Resources/2015/Metropolitan Median House Sales Q1 2015.csv"))
Q2_2015 = pd.read_csv(Path("Resources/2015/Metropolitan Median House Sales Q2 2015.csv"))
Q3_2015 = pd.read_csv(Path("Resources/2015/Metropolitan Median House Sales Q3 2015.csv"))
Q4_2015 = pd.read_csv(Path("Resources/2015/Metropolitan Median House Sales Q4 2015.csv"))

Q1_2016 = pd.read_csv(Path("Resources/2016/Metropolitan Median House Sales Q1 2016.csv"))
Q2_2016 = pd.read_csv(Path("Resources/2016/Metropolitan Median House Sales Q2 2016.csv"))
Q3_2016 = pd.read_csv(Path("Resources/2016/Metropolitan Median House Sales Q3 2016.csv"))
Q4_2016 = pd.read_csv(Path("Resources/2016/Metropolitan Median House Sales Q4 2016.csv"))

Q1_2017 = pd.read_csv(Path("Resources/2017/Metropolitan Median House Sales Q1 2017.csv"))
Q2_2017 = pd.read_csv(Path("Resources/2017/Metropolitan Median House Sales Q2 2017.csv"))
Q3_2017 = pd.read_csv(Path("Resources/2017/Metropolitan Median House Sales Q3 2017.csv"))
Q4_2017 = pd.read_csv(Path("Resources/2017/Metropolitan Median House Sales Q4 2017.csv"))

Q1_2018 = pd.read_csv(Path("Resources/2018/Metropolitan Median House Sales Q1 2018.csv"))
Q2_2018 = pd.read_csv(Path("Resources/2018/Metropolitan Median House Sales Q2 2018.csv"))
Q3_2018 = pd.read_csv(Path("Resources/2018/Metropolitan Median House Sales Q3 2018.csv"))
Q4_2018 = pd.read_csv(Path("Resources/2018/Metropolitan Median House Sales Q4 2018.csv"))

Q1_2019 = pd.read_csv(Path("Resources/2019/Metropolitan Median House Sales Q1 2019.csv"))
Q2_2019 = pd.read_csv(Path("Resources/2019/Metropolitan Median House Sales Q2 2019.csv"))
Q3_2019 = pd.read_csv(Path("Resources/2019/Metropolitan Median House Sales Q3 2019.csv"))
Q4_2019 = pd.read_csv(Path("Resources/2019/Metropolitan Median House Sales Q4 2019.csv"))

Q1_2020 = pd.read_csv(Path("Resources/2020/Metropolitan Median House Sales Q1 2020.csv"))
Q2_2020 = pd.read_csv(Path("Resources/2020/Metropolitan Median House Sales Q2 2020.csv"))
Q3_2020 = pd.read_csv(Path("Resources/2020/Metropolitan Median House Sales Q3 2020.csv"))
Q4_2020 = pd.read_csv(Path("Resources/2020/Metropolitan Median House Sales Q4 2020.csv"))

Q1_2021 = pd.read_csv(Path("Resources/2021/Metropolitan Median House Sales Q1 2021.csv"))
Q2_2021 = pd.read_csv(Path("Resources/2021/Metropolitan Median House Sales Q2 2021.csv"))
Q3_2021 = pd.read_csv(Path("Resources/2021/Metropolitan Median House Sales Q3 2021.csv"))
Q4_2021 = pd.read_csv(Path("Resources/2021/Metropolitan Median House Sales Q4 2021.csv"))

Q1_2022 = pd.read_csv(Path("Resources/2022/Metropolitan Median House Sales Q1 2022.csv"))
Q2_2022 = pd.read_csv(Path("Resources/2022/Metropolitan Median House Sales Q2 2022.csv"))
Q3_2022 = pd.read_csv(Path("Resources/2022/Metropolitan Median House Sales Q3 2022.csv"))
Q4_2022 = pd.read_csv(Path("Resources/2022/Metropolitan Median House Sales Q4 2022.csv"))

Q1_2023 = pd.read_csv(Path("Resources/2023/Metropolitan Median House Sales Q1 2023.csv"))
Q2_2023 = pd.read_csv(Path("Resources/2023/Metropolitan Median House Sales Q2 2023.csv"))

# Combine quarters into individual years
data_2015 = pd.concat([Q1_2015, Q2_2015, Q3_2015, Q4_2015], axis =1)

data_2016 = pd.concat([Q1_2016, Q2_2016, Q3_2016, Q4_2016], axis =1)

data_2017 = pd.concat([Q1_2017, Q2_2017, Q3_2017, Q4_2017], axis =1)

data_2018 = pd.concat([Q1_2018, Q2_2018, Q3_2018, Q4_2018], axis =1)

data_2019 = pd.concat([Q1_2019, Q2_2019, Q3_2019, Q4_2019], axis =1)

data_2020 = pd.concat([Q1_2020, Q2_2020, Q3_2020, Q4_2020], axis =1)

data_2021 = pd.concat([Q1_2021, Q2_2021, Q3_2021, Q4_2021], axis =1)

data_2022 = pd.concat([Q1_2022, Q2_2022, Q3_2022, Q4_2022], axis =1)

data_2023 = pd.concat([Q1_2023, Q2_2023], axis =1)

# %%
Q1_2015
# Out:
#                      City                 Suburb  Sales\n1Q 2014  \
# 0    ADELAIDE              ADELAIDE                          5.0
# 1    ADELAIDE              NORTH ADELAIDE                    9.0
# 2    ADELAIDE HILLS        ALDGATE                          16.0
# 3    ADELAIDE HILLS        ASHTON                            NaN
# 4    ADELAIDE HILLS        BALHANNAH                         1.0
# ..                    ...                    ...             ...
# 528  WEST TORRENS          THEBARTON                         2.0
# 529  WEST TORRENS          TORRENSVILLE                     12.0
# 530  WEST TORRENS          UNDERDALE                         7.0
# 531  WEST TORRENS          WEST BEACH                       15.0
# 532  WEST TORRENS          WEST RICHMOND                     4.0
#
#      Median\n1Q 2014  Sales\n1Q 2015  Median\n1Q 2015 Median\nChange  \
# 0           647500.0             6.0         757500.0         16.99%
# ...

# %%
Q2_2015
# Out:
#                City          Suburb  Sales\n2Q 2014  Median\n2Q 2014  \
# 0          ADELAIDE        ADELAIDE             7.0         642500.0
# 1          ADELAIDE  NORTH ADELAIDE            17.0        1250000.0
# 2    ADELAIDE HILLS         ALDGATE            16.0         680000.0
# 3    ADELAIDE HILLS          ASHTON             NaN              NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN              NaN
# ..              ...             ...             ...              ...
# 478    WEST TORRENS    TORRENSVILLE            12.0         485500.0
# 479    WEST TORRENS       UNDERDALE             9.0         610000.0
# 480    WEST TORRENS      WEST BEACH            18.0         560000.0
# 481    WEST TORRENS   WEST RICHMOND             4.0         390794.0
# 482             NaN             NaN             NaN              NaN
#
#      Sales\n2Q 2015  Median\n2Q 2015 Median\nChange
# 0               9.0         785000.0          22.2%
# ...

# %%
Q3_2015
# Out:
#                City          Suburb  Sales\n3Q 2014 Median\n3Q 2014  \
# 0          ADELAIDE        ADELAIDE             5.0         960,000
# 1          ADELAIDE  NORTH ADELAIDE             9.0         850,000
# 2    ADELAIDE HILLS         ALDGATE             6.0         550,000
# 3    ADELAIDE HILLS          ASHTON             1.0         469,000
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 472    WEST TORRENS       THEBARTON             5.0         440,000
# 473    WEST TORRENS    TORRENSVILLE            15.0         532,500
# 474    WEST TORRENS       UNDERDALE             6.0         578,000
# 475    WEST TORRENS      WEST BEACH            15.0         639,250
# 476    WEST TORRENS   WEST RICHMOND             3.0         385,000
#
#      Sales\n3Q 2015 Median\n3Q 2015 Median\nChange
# 0               5.0         600,000        -37.50%
# ...

# %%
Q4_2015
# Out:
#                City          Suburb  Sales\n4Q 2014 Median\n4Q 2014  \
# 0          ADELAIDE        ADELAIDE             5.0         770,000
# 1          ADELAIDE  NORTH ADELAIDE            10.0         952,500
# 2    ADELAIDE HILLS         ALDGATE            10.0         670,000
# 3    ADELAIDE HILLS          ASHTON             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 473    WEST TORRENS    TORRENSVILLE            11.0         545,000
# 474    WEST TORRENS       UNDERDALE             6.0         517,500
# 475    WEST TORRENS      WEST BEACH            17.0         641,250
# 476    WEST TORRENS   WEST RICHMOND             2.0         380,000
# 477             NaN             NaN             NaN             NaN
#
#      Sales\n4Q 2015 Median\n4Q 2015 Median\nChange
# 0               5.0         320,000        -58.44%
# 1               4.0       1,300,000         36.48%
# ...

# %%
data_2015
# Out:
#                      City                 Suburb  Sales\n1Q 2014  \
# 0    ADELAIDE              ADELAIDE                          5.0
# 1    ADELAIDE              NORTH ADELAIDE                    9.0
# 2    ADELAIDE HILLS        ALDGATE                          16.0
# 3    ADELAIDE HILLS        ASHTON                            NaN
# 4    ADELAIDE HILLS        BALHANNAH                         1.0
# ..                    ...                    ...             ...
# 528  WEST TORRENS          THEBARTON                         2.0
# 529  WEST TORRENS          TORRENSVILLE                     12.0
# 530  WEST TORRENS          UNDERDALE                         7.0
# 531  WEST TORRENS          WEST BEACH                       15.0
# 532  WEST TORRENS          WEST RICHMOND                     4.0
#
#      Median\n1Q 2014  Sales\n1Q 2015  Median\n1Q 2015  Median\nChange  \
# 0           647500.0             6.0         757500.0          16.99%
# ...

# %%
data_2016
# Out:
#                City          Suburb  Sales\n1Q 2015 Median\n1Q 2015  \
# 0          ADELAIDE        ADELAIDE             6.0         757,500
# 1          ADELAIDE  NORTH ADELAIDE             4.0         992,500
# 2    ADELAIDE HILLS         ALDGATE            17.0         650,000
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             1.0         951,000
# ..              ...             ...             ...             ...
# 473    WEST TORRENS    TORRENSVILLE            12.0         545,000
# 474    WEST TORRENS       UNDERDALE            11.0         560,000
# 475    WEST TORRENS      WEST BEACH            18.0         770,000
# 476    WEST TORRENS   WEST RICHMOND             2.0         363,000
# 477             NaN             NaN             NaN             NaN
#
#      Sales\n1Q 2016 Median\n1Q 2016 Median\nChange            City  \
# 0               3.0         750,000         -0.99%        ADELAIDE
# ...

# %%
data_2017
# Out:
#                City          Suburb  Sales\n1Q 2016 Median\n1Q 2016  \
# 0          ADELAIDE        ADELAIDE             5.0         792,500
# 1          ADELAIDE  NORTH ADELAIDE            12.0       1,050,000
# 2    ADELAIDE HILLS         ALDGATE            16.0         710,000
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 474    WEST TORRENS    TORRENSVILLE            11.0         530,000
# 475    WEST TORRENS       UNDERDALE             3.0         519,000
# 476    WEST TORRENS      WEST BEACH             7.0         810,000
# 477    WEST TORRENS   WEST RICHMOND             4.0         425,000
# 478             NaN             NaN             NaN             NaN
#
#      Sales\n1Q 2017 Median\n1Q 2017 Median\nChange            City  \
# 0               6.0         627,500        -20.82%        ADELAIDE
# ...

# %%
data_2018
# Out:
#                City          Suburb  Sales\n1Q 2017 Median\n1Q 2017  \
# 0          ADELAIDE        ADELAIDE             6.0         673,750
# 1          ADELAIDE  NORTH ADELAIDE             7.0       1,100,000
# 2    ADELAIDE HILLS         ALDGATE            18.0         782,500
# 3    ADELAIDE HILLS          ASHTON             1.0         415,000
# 4    ADELAIDE HILLS    BASKET RANGE             1.0         470,000
# ..              ...             ...             ...             ...
# 474    WEST TORRENS       THEBARTON             3.0         568,000
# 475    WEST TORRENS    TORRENSVILLE            12.0         570,000
# 476    WEST TORRENS       UNDERDALE             4.0         572,500
# 477    WEST TORRENS      WEST BEACH            12.0         684,000
# 478    WEST TORRENS   WEST RICHMOND             2.0         419,600
#
#      Sales\n1Q 2018 Median\n1Q 2018 Median\nChange            City  \
# 0               5.0         861,000         27.79%        ADELAIDE
# ...

# %%
data_2019
# Out:
#                City          Suburb  Sales\n1Q 2018 Median\n1Q 2018  \
# 0          ADELAIDE        ADELAIDE             5.0         861,000
# 1          ADELAIDE  NORTH ADELAIDE             2.0       2,195,500
# 2    ADELAIDE HILLS         ALDGATE            17.0         696,000
# 3    ADELAIDE HILLS          ASHTON             3.0         681,200
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 474    WEST TORRENS       THEBARTON             5.0         547,500
# 475    WEST TORRENS    TORRENSVILLE            15.0         545,000
# 476    WEST TORRENS       UNDERDALE             8.0         610,500
# 477    WEST TORRENS      WEST BEACH            13.0         691,250
# 478    WEST TORRENS   WEST RICHMOND             7.0         430,000
#
#      Sales\n1Q 2019 Median\n1Q 2019 Median\nChange            City  \
# 0               4.0       1,002,500         16.43%        ADELAIDE
# ...

# %%
data_2020
# Out:
#                City          Suburb  Sales\n1Q 2019 Median\n1Q 2019  \
# 0          ADELAIDE        ADELAIDE             4.0       1,002,500
# 1          ADELAIDE  NORTH ADELAIDE            10.0         972,000
# 2    ADELAIDE HILLS         ALDGATE            16.0         830,000
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 474    WEST TORRENS       THEBARTON             NaN             NaN
# 475    WEST TORRENS    TORRENSVILLE             7.0         588,000
# 476    WEST TORRENS       UNDERDALE             5.0         700,000
# 477    WEST TORRENS      WEST BEACH            16.0         852,500
# 478    WEST TORRENS   WEST RICHMOND             4.0         510,000
#
#      Sales\n1Q 2020 Median\n1Q 2020 Median\nChange            City  \
# 0               6.0         810,000        -19.20%        ADELAIDE
# ...

# %%
data_2021
# Out:
#                City          Suburb  Sales\n1Q 2020 Median\n1Q 2020  \
# 0          ADELAIDE        ADELAIDE             6.0         810,000
# 1          ADELAIDE  NORTH ADELAIDE            16.0       1,370,000
# 2    ADELAIDE HILLS         ALDGATE            10.0         797,500
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 474    WEST TORRENS       THEBARTON             2.0         745,000
# 475    WEST TORRENS    TORRENSVILLE             9.0         676,000
# 476    WEST TORRENS       UNDERDALE             9.0         660,000
# 477    WEST TORRENS      WEST BEACH            14.0         885,000
# 478    WEST TORRENS   WEST RICHMOND             3.0         462,500
#
#      Sales\n1Q 2021 Median\n1Q 2021 Median\nChange            City  \
# 0               8.0       1,013,000         25.06%        ADELAIDE
# ...

# %%
data_2022
# Out:
#                City          Suburb  Sales\n1Q 2021 Median\n1Q 2021  \
# 0          ADELAIDE        ADELAIDE             8.0       1,013,000
# 1          ADELAIDE  NORTH ADELAIDE            12.0       2,205,000
# 2    ADELAIDE HILLS         ALDGATE            14.0         875,000
# 3    ADELAIDE HILLS          ASHTON             1.0         940,000
# 4    ADELAIDE HILLS    BASKET RANGE             1.0         725,000
# ..              ...             ...             ...             ...
# 475    WEST TORRENS       THEBARTON             4.0         625,000
# 476    WEST TORRENS    TORRENSVILLE            13.0         620,000
# 477    WEST TORRENS       UNDERDALE            10.0         890,000
# 478    WEST TORRENS      WEST BEACH            11.0         899,500
# 479    WEST TORRENS   WEST RICHMOND             5.0         485,000
#
#      Sales\n1Q 2022 Median\n1Q 2022 Median\nChange            City  \
# 0               2.0       1,266,250         25.00%        ADELAIDE
# ...

# %%
data_2023
# Out:
#                City          Suburb  Sales\n1Q 2014 Median\n1Q 2014  \
# 0          ADELAIDE        ADELAIDE             2.0       1,266,250
# 1          ADELAIDE  NORTH ADELAIDE             4.0       1,617,500
# 2    ADELAIDE HILLS         ALDGATE             6.0         870,000
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 477    WEST TORRENS    TORRENSVILLE            12.0         941,500
# 478    WEST TORRENS       UNDERDALE             9.0         775,556
# 479    WEST TORRENS      WEST BEACH            17.0       1,020,000
# 480    WEST TORRENS   WEST RICHMOND             NaN             NaN
# 481             NaN             NaN             NaN             NaN
#
#      Sales\n1Q 2015 Median\n1Q 2015 Median\nChange            City  \
# 0               2.0       1,205,000         -4.84%        ADELAIDE
# ...

# %%
Q1_2023
# Out:
#                City          Suburb  Sales\n1Q 2014 Median\n1Q 2014  \
# 0          ADELAIDE        ADELAIDE             2.0       1,266,250
# 1          ADELAIDE  NORTH ADELAIDE             4.0       1,617,500
# 2    ADELAIDE HILLS         ALDGATE             6.0         870,000
# 3    ADELAIDE HILLS          ASHTON             NaN             NaN
# 4    ADELAIDE HILLS    BASKET RANGE             NaN             NaN
# ..              ...             ...             ...             ...
# 476    WEST TORRENS       THEBARTON             9.0         832,500
# 477    WEST TORRENS    TORRENSVILLE            12.0         941,500
# 478    WEST TORRENS       UNDERDALE             9.0         775,556
# 479    WEST TORRENS      WEST BEACH            17.0       1,020,000
# 480    WEST TORRENS   WEST RICHMOND             NaN             NaN
#
#      Sales\n1Q 2015 Median\n1Q 2015 Median\nChange
# 0               2.0       1,205,000         -4.84%
# ...
